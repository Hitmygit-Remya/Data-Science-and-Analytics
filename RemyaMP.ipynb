# %% [markdown]
# # Importing Python Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data from file

# %%
Myiris=pd.read_excel('../MY PC/iris.xls')
Myiris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display Column Names

# %%
Myiris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Mean of each columns in a dataset

# %%
Myiris.mean()
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_18272\2348489106.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Myiris.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Null Handling

# %%
Myiris.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # PL Plot

# %%
plt.figure(figsize = (12, 9))
x = Myiris.PL
  
plt.hist(x, bins = 24, color = "blue")
plt.title("PL")
plt.xlabel("PL")
plt.ylabel("Count")
  
plt.show()

# %% [markdown]
# # Box Plot

# %%
NewIris=Myiris[["SL","SW","PL","PW"]]

plt.figure(figsize = (20, 9))
NewIris.boxplot()
# Out:
# <AxesSubplot:>
